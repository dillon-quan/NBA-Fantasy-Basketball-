# %%
import os
import re
import numpy as np
import pandas as pd

# %%
from nba_api.stats.endpoints import fantasywidget
fantasy = fantasywidget.FantasyWidget()
df = fantasy.get_data_frames()[0]

# %%
df.head()
# Out:
#    PLAYER_ID            PLAYER_NAME PLAYER_POSITION     TEAM_ID  \
# 0     203999           Nikola Jokic               C  1610612743
# 1     203507  Giannis Antetokounmpo               F  1610612749
# 2     201935           James Harden               G  1610612751
# 3    1629029            Luka Doncic             F-G  1610612742
# 4     203954            Joel Embiid             C-F  1610612755
#
#   TEAM_ABBREVIATION  GP   MIN  FAN_DUEL_PTS  NBA_FANTASY_PTS   PTS   REB  \
# 0               DEN  58  35.4          53.7             55.8  26.4  11.0
# 1               MIL  49  33.8          52.2             54.7  28.5  11.3
# 2               BKN  42  37.1          50.8             52.7  25.2   8.0
# 3               DAL  53  35.1          50.3             52.0  28.7   8.0
# 4               PHI  41  32.1          49.7             52.1  30.0  11.1
#
#     AST   BLK   STL  TOV  FG3M   FGA  FG_PCT   FTA  FT_PCT
# 0   8.7  0.66  1.41  3.1   1.4  18.3   0.568   5.0   0.854
# 1   6.0  1.27  1.16  3.7   1.1  18.3   0.564  10.0   0.683
# 2  10.9  0.69  1.19  4.1   2.8  17.2   0.463   7.5   0.870
# 3   8.7  0.64  1.02  4.3   3.0  21.0   0.484   7.4   0.726
# 4   3.1  1.41  1.00  3.2   1.2  18.4   0.513  11.7   0.851

# %%
df.loc[(df.PLAYER_NAME == 'Stephen Curry')]
# Out:
#    PLAYER_ID    PLAYER_NAME PLAYER_POSITION     TEAM_ID TEAM_ABBREVIATION  GP  \
# 7     201939  Stephen Curry               G  1610612744               GSW  51
#
#     MIN  FAN_DUEL_PTS  NBA_FANTASY_PTS   PTS  REB  AST   BLK  STL  TOV  FG3M  \
# 7  34.0          45.9             47.3  31.1  5.5  5.9  0.12  1.2  3.3   5.1
#
#     FGA  FG_PCT  FTA  FT_PCT
# 7  21.0   0.486  6.0   0.922

# %%
# get teams data
from nba_api.stats.static import teams
df_teams = pd.DataFrame(teams.get_teams())
df_teams.rename(columns={'id': 'team_id'}, inplace=True)
df_teams.head()
# Out:
#       team_id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
merged = df.merge(df_teams[['abbreviation', 'full_name']], left_on='TEAM_ABBREVIATION', right_on='abbreviation', how='inner')
merged.rename(columns={'full_name': 'TEAM_NAME'}, inplace=True)

# %%
matchup = pd.read_csv('../data/2021_schedule.csv')

# %%
columns = ['PLAYER_ID', 'PLAYER_NAME', 'PLAYER_POSITION', 'TEAM_ID',
       'TEAM_ABBREVIATION', 'GP', 'MIN', 'PTS', 'REB', 'AST', 'BLK', 'STL', 'TOV', 'FG3M', 'FGA', 'FG_PCT',
       'FTA', 'FT_PCT', 'TEAM_NAME']

# %%
merged[columns]
# Out:
#      PLAYER_ID         PLAYER_NAME PLAYER_POSITION     TEAM_ID  \
# 0       203999        Nikola Jokic               C  1610612743
# 1      1627750        Jamal Murray               G  1610612743
# 2      1629008  Michael Porter Jr.               F  1610612743
# 3       203932        Aaron Gordon               F  1610612743
# 4       203115         Will Barton               G  1610612743
# ..         ...                 ...             ...         ...
# 520    1630181        R.J. Hampton               G  1610612753
# 521    1629606       Robert Franks               F  1610612753
# 522    1629648         Jordan Bone               G  1610612753
# 523    1629962       Devin Cannady               G  1610612753
# 524    1630211          Karim Mane               G  1610612753
#
#     TEAM_ABBREVIATION  GP   MIN   PTS   REB  AST   BLK   STL  TOV  FG3M   FGA  \
# 0                 DEN  58  35.4  26.4  11.0  8.7  0.66  1.41  3.1   1.4  18.3
# 1                 DEN  48  35.5  21.2   4.0  4.8  0.27  1.33  2.3   2.7  16.5
# 2                 DEN  48  30.9  17.6   7.7  1.0  0.92  0.60  1.1   2.4  12.6
# 3                 DEN  38  28.6  13.3   6.1  3.7  0.74  0.71  2.2   1.4  10.5
# 4                 DEN  55  31.5  12.9   4.1  3.3  0.42  0.91  1.7   1.8  11.1
# ..                ...  ..   ...   ...   ...  ...   ...   ...  ...   ...   ...
# 520               ORL  39  14.1   4.9   2.7  0.9  0.15  0.44  0.8   0.4   4.6
# 521               ORL   5  13.2   4.4   1.8  0.6  0.60  0.20  0.4   0.6   3.0
# 522               ORL  14  14.0   4.0   1.7  1.3  0.00  0.14  0.2   0.7   3.9
# 523               ORL   7  10.5   4.9   0.7  0.1  0.14  0.71  0.3   0.9   4.0
# 524               ORL  10   8.8   1.1   1.4  0.4  0.20  0.00  0.3   0.1   1.3
#
#      FG_PCT  FTA  FT_PCT       TEAM_NAME
# 0     0.568  5.0   0.854  Denver Nuggets
# 1     0.477  3.2   0.869  Denver Nuggets
# 2     0.541  2.1   0.772  Denver Nuggets
# 3     0.460  3.4   0.651  Denver Nuggets
# 4     0.426  2.2   0.785  Denver Nuggets
# ..      ...  ...     ...             ...
# 520   0.425  0.9   0.649   Orlando Magic
# 521   0.400  1.6   0.875   Orlando Magic
# 522   0.426  0.0   0.000   Orlando Magic
# 523   0.393  1.0   0.857   Orlando Magic
# 524   0.231  0.5   0.800   Orlando Magic
#
# [525 rows x 19 columns]

# %%
temp = matchup.loc[(matchup.week == 'Week 17')]
temp
# Out:
#            date                 visitor  vistor_pts                    home  \
# 850  04/19/2021     Cleveland Cavaliers       105.0         Detroit Pistons
# 851  04/19/2021           Chicago Bulls       102.0          Boston Celtics
# 852  04/19/2021   Golden State Warriors       107.0      Philadelphia 76ers
# 853  04/19/2021       San Antonio Spurs       109.0          Indiana Pacers
# 854  04/19/2021         Houston Rockets        91.0              Miami Heat
# 855  04/19/2021            Phoenix Suns       128.0         Milwaukee Bucks
# 856  04/19/2021   Oklahoma City Thunder       107.0      Washington Wizards
# 857  04/19/2021       Memphis Grizzlies       137.0          Denver Nuggets
# 858  04/19/2021               Utah Jazz       111.0      Los Angeles Lakers
# 859  04/20/2021           Orlando Magic        96.0           Atlanta Hawks
# 860  04/20/2021           Brooklyn Nets       134.0    New Orleans Pelicans
# 861  04/20/2021       Charlotte Hornets        97.0         New York Knicks
# 862  04/20/2021    Los Angeles Clippers       113.0  Portland Trail Blazers
# 863  04/20/2021  Minnesota Timberwolves       134.0        Sacramento Kings
# 864  04/21/2021           Chicago Bulls       105.0     Cleveland Cavaliers
# 865  04/21/2021   Oklahoma City Thunder       116.0          Indiana Pacers
# 866  04/21/2021            Phoenix Suns       116.0      Philadelphia 76ers
# 867  04/21/2021           Brooklyn Nets       103.0         Toronto Raptors
# 868  04/21/2021   Golden State Warriors       114.0      Washington Wizards
# 869  04/21/2021               Utah Jazz       112.0         Houston Rockets
# 870  04/21/2021           Atlanta Hawks       127.0         New York Knicks
# 871  04/21/2021         Detroit Pistons       117.0        Dallas Mavericks
# 872  04/21/2021              Miami Heat       107.0       San Antonio Spurs
# 873  04/21/2021       Memphis Grizzlies       105.0    Los Angeles Clippers
# 874  04/21/2021          Denver Nuggets       106.0  Portland Trail Blazers
# 875  04/21/2021  Minnesota Timberwolves       125.0        Sacramento Kings
# 876  04/22/2021            Phoenix Suns        86.0          Boston Celtics
# 877  04/22/2021      Philadelphia 76ers       117.0         Milwaukee Bucks
# 878  04/22/2021    New Orleans Pelicans       135.0           Orlando Magic
# 879  04/22/2021         Detroit Pistons        91.0       San Antonio Spurs
# 880  04/22/2021       Charlotte Hornets        91.0           Chicago Bulls
# 881  04/22/2021      Los Angeles Lakers       110.0        Dallas Mavericks
# 882  04/23/2021              Miami Heat         NaN           Atlanta Hawks
# 883  04/23/2021          Boston Celtics         NaN           Brooklyn Nets
# 884  04/23/2021     Cleveland Cavaliers         NaN       Charlotte Hornets
# 885  04/23/2021    Los Angeles Clippers         NaN         Houston Rockets
# 886  04/23/2021      Washington Wizards         NaN   Oklahoma City Thunder
# 887  04/23/2021          Denver Nuggets         NaN   Golden State Warriors
# 888  04/23/2021       Memphis Grizzlies         NaN  Portland Trail Blazers
# 889  04/24/2021         Toronto Raptors         NaN         New York Knicks
# 890  04/24/2021      Philadelphia 76ers         NaN         Milwaukee Bucks
# 891  04/24/2021         Detroit Pistons         NaN          Indiana Pacers
# 892  04/24/2021           Chicago Bulls         NaN              Miami Heat
# 893  04/24/2021       San Antonio Spurs         NaN    New Orleans Pelicans
# 894  04/24/2021      Los Angeles Lakers         NaN        Dallas Mavericks
# 895  04/24/2021  Minnesota Timberwolves         NaN               Utah Jazz
# 896  04/24/2021         Houston Rockets         NaN          Denver Nuggets
# 897  04/25/2021          Boston Celtics         NaN       Charlotte Hornets
# 898  04/25/2021            Phoenix Suns         NaN           Brooklyn Nets
# 899  04/25/2021       Memphis Grizzlies         NaN  Portland Trail Blazers
# 900  04/25/2021     Cleveland Cavaliers         NaN      Washington Wizards
# 901  04/25/2021         Milwaukee Bucks         NaN           Atlanta Hawks
# 902  04/25/2021          Indiana Pacers         NaN           Orlando Magic
# 903  04/25/2021        Sacramento Kings         NaN   Golden State Warriors
#
#      home_pts  dow     week
# 850     109.0  Mon  Week 17
# 851      96.0  Mon  Week 17
# 852      96.0  Mon  Week 17
# 853      94.0  Mon  Week 17
# 854     113.0  Mon  Week 17
# 855     127.0  Mon  Week 17
# 856     119.0  Mon  Week 17
# 857     139.0  Mon  Week 17
# 858      97.0  Mon  Week 17
# 859     112.0  Tue  Week 17
# 860     129.0  Tue  Week 17
# 861     109.0  Tue  Week 17
# 862     112.0  Tue  Week 17
# 863     120.0  Tue  Week 17
# 864     121.0  Wed  Week 17
# 865     122.0  Wed  Week 17
# 866     113.0  Wed  Week 17
# 867     114.0  Wed  Week 17
# 868     118.0  Wed  Week 17
# 869      89.0  Wed  Week 17
# 870     137.0  Wed  Week 17
# 871     127.0  Wed  Week 17
# 872      87.0  Wed  Week 17
# 873     117.0  Wed  Week 17
# 874     105.0  Wed  Week 17
# 875     128.0  Wed  Week 17
# 876      99.0  Thu  Week 17
# 877     124.0  Thu  Week 17
# 878     100.0  Thu  Week 17
# 879     106.0  Thu  Week 17
# 880     108.0  Thu  Week 17
# 881     115.0  Thu  Week 17
# 882       NaN  Fri  Week 17
# 883       NaN  Fri  Week 17
# 884       NaN  Fri  Week 17
# 885       NaN  Fri  Week 17
# 886       NaN  Fri  Week 17
# 887       NaN  Fri  Week 17
# 888       NaN  Fri  Week 17
# 889       NaN  Sat  Week 17
# 890       NaN  Sat  Week 17
# 891       NaN  Sat  Week 17
# 892       NaN  Sat  Week 17
# 893       NaN  Sat  Week 17
# 894       NaN  Sat  Week 17
# 895       NaN  Sat  Week 17
# 896       NaN  Sat  Week 17
# 897       NaN  Sun  Week 17
# 898       NaN  Sun  Week 17
# 899       NaN  Sun  Week 17
# 900       NaN  Sun  Week 17
# 901       NaN  Sun  Week 17
# 902       NaN  Sun  Week 17
# 903       NaN  Sun  Week 17

# %%
t1 = temp[['visitor', 'home']]
t2 = temp[['home', 'visitor']].rename(columns={'home':'visitor', 'visitor':'home'})
test = pd.concat([t1,t2])
test
# Out:
#                     visitor                 home
# 850     Cleveland Cavaliers      Detroit Pistons
# 851           Chicago Bulls       Boston Celtics
# 852   Golden State Warriors   Philadelphia 76ers
# 853       San Antonio Spurs       Indiana Pacers
# 854         Houston Rockets           Miami Heat
# ..                      ...                  ...
# 899  Portland Trail Blazers    Memphis Grizzlies
# 900      Washington Wizards  Cleveland Cavaliers
# 901           Atlanta Hawks      Milwaukee Bucks
# 902           Orlando Magic       Indiana Pacers
# 903   Golden State Warriors     Sacramento Kings
#
# [108 rows x 2 columns]

# %%
player = merged.loc[(merged.PLAYER_NAME == 'Stephen Curry')]

# %%
opps_team = test.loc[(test.visitor == player.TEAM_NAME.values[0]), 'home'].values

# %%
player
# Out:
#      PLAYER_ID    PLAYER_NAME PLAYER_POSITION     TEAM_ID TEAM_ABBREVIATION  \
# 131     201939  Stephen Curry               G  1610612744               GSW
#
#      GP   MIN  FAN_DUEL_PTS  NBA_FANTASY_PTS   PTS  ...   BLK  STL  TOV  FG3M  \
# 131  51  34.0          45.9             47.3  31.1  ...  0.12  1.2  3.3   5.1
#
#       FGA  FG_PCT  FTA  FT_PCT  abbreviation              TEAM_NAME
# 131  21.0   0.486  6.0   0.922           GSW  Golden State Warriors
#
# [1 rows x 22 columns]

# %%
merged.loc[(merged.PLAYER_POSITION.str.contains(player.PLAYER_POSITION.values[0])) &
           (merged.TEAM_NAME.isin(opps_team)), columns]
# Out:
#      PLAYER_ID         PLAYER_NAME PLAYER_POSITION     TEAM_ID  \
# 1      1627750        Jamal Murray               G  1610612743
# 4       203115         Will Barton               G  1610612743
# 6      1628420        Monte Morris               G  1610612743
# 9      1628408           PJ Dozier             G-F  1610612743
# 10      203085       Austin Rivers               G  1610612743
# 11     1630267    Facundo Campazzo               G  1610612743
# 16     1627885  Shaquille Harrison               G  1610612743
# 17     1630210       Markus Howard               G  1610612743
# 76     1627732         Ben Simmons             G-F  1610612755
# 77     1629003        Shake Milton             G-F  1610612755
# 78      201980         Danny Green               G  1610612755
# 79      203552          Seth Curry               G  1610612755
# 81      201588         George Hill               G  1610612755
# 82     1627788      Furkan Korkmaz             G-F  1610612755
# 83     1629680    Matisse Thybulle             G-F  1610612755
# 84     1630178        Tyrese Maxey               G  1610612755
# 85     1629751      Dakota Mathias               G  1610612755
# 87     1630222         Mason Jones               G  1610612755
# 90     1630198          Isaiah Joe               G  1610612755
# 91     1629730       Rayjon Tucker               G  1610612755
# 94     1628390   Terrance Ferguson               G  1610612755
# 95      201566   Russell Westbrook               G  1610612764
# 96      203078        Bradley Beal               G  1610612764
# 100     202397           Ish Smith               G  1610612764
# 101     203526           Raul Neto               G  1610612764
# 107    1629010     Jerome Robinson               G  1610612764
# 108    1629726    Garrison Mathews               G  1610612764
# 109    1628990  Chandler Hutchison             F-G  1610612764
# 110    1629067         Isaac Bonga               G  1610612764
# 111    1630216     Cassius Winston               G  1610612764
# 313    1628368        De'Aaron Fox               G  1610612758
# 316    1627741         Buddy Hield               G  1610612758
# 317    1630169   Tyrese Haliburton               G  1610612758
# 319    1626153        Delon Wright               G  1610612758
# 321    1629056       Terence Davis               G  1610612758
# 323     203090    Maurice Harkless             F-G  1610612758
# 326    1629657            Kyle Guy               G  1610612758
# 328    1629713        Justin James             G-F  1610612758
# 330    1630186     Jahmi'us Ramsey               G  1610612758
#
#     TEAM_ABBREVIATION  GP   MIN   PTS   REB   AST   BLK   STL  TOV  FG3M  \
# 1                 DEN  48  35.5  21.2   4.0   4.8  0.27  1.33  2.3   2.7
# 4                 DEN  55  31.5  12.9   4.1   3.3  0.42  0.91  1.7   1.8
# 6                 DEN  44  26.1  10.3   2.2   3.2  0.30  0.70  0.7   1.1
# 9                 DEN  43  20.7   7.1   3.7   1.7  0.42  0.60  0.9   0.9
# 10                DEN  22  20.7   7.2   2.3   1.9  0.00  0.55  1.0   1.3
# 11                DEN  52  19.4   5.2   1.7   2.8  0.21  1.00  1.0   1.2
# 16                DEN  20   4.5   1.3   0.5   0.6  0.00  0.25  0.3   0.0
# 17                DEN  27   3.3   1.0   0.4   0.4  0.00  0.07  0.2   0.2
# 76                PHI  48  33.3  14.8   7.6   7.1  0.65  1.60  3.3   0.1
# 77                PHI  51  23.9  13.4   2.3   3.0  0.25  0.63  1.8   1.1
# 78                PHI  58  28.4   9.7   3.7   1.7  0.86  1.31  1.0   2.6
# 79                PHI  46  29.0  12.1   2.1   2.8  0.17  0.78  1.2   2.0
# 81                PHI  17  25.3  10.8   2.1   2.8  0.29  0.71  0.9   1.4
# 82                PHI  47  19.8   9.5   2.1   1.3  0.17  0.94  0.9   1.9
# 83                PHI  56  20.0   3.8   2.0   0.9  1.04  1.52  0.4   0.7
# 84                PHI  50  14.6   7.2   1.5   1.7  0.16  0.38  0.6   0.4
# 85                PHI   8  15.4   6.0   0.9   1.6  0.38  0.13  0.1   1.0
# 87                PHI  30  10.8   5.4   1.8   1.4  0.03  0.20  0.9   0.8
# 90                PHI  31   9.3   3.2   0.9   0.5  0.13  0.26  0.2   0.8
# 91                PHI  10   3.4   1.6   0.8   0.4  0.00  0.10  0.2   0.1
# 94                PHI  13   3.8   0.2   0.1   0.2  0.00  0.08  0.3   0.0
# 95                WAS  51  35.6  21.6  11.1  10.9  0.35  1.33  5.1   1.3
# 96                WAS  49  35.4  31.0   4.8   4.7  0.35  1.20  3.2   2.2
# 100               WAS  30  20.3   6.0   3.4   4.2  0.23  0.63  1.0   0.4
# 101               WAS  52  20.7   8.1   2.3   2.1  0.08  1.13  0.8   0.9
# 107               WAS  17  17.9   4.9   2.2   1.5  0.35  0.71  1.1   0.6
# 108               WAS  52  17.5   5.8   1.4   0.5  0.12  0.50  0.2   1.3
# 109               WAS  13  13.5   3.7   3.3   0.7  0.00  0.31  1.1   0.2
# 110               WAS  36  11.3   2.1   1.8   0.6  0.22  0.28  0.5   0.3
# 111               WAS  17   5.3   2.1   0.5   0.6  0.06  0.12  0.1   0.4
# 313               SAC  58  35.1  25.2   3.5   7.2  0.47  1.50  3.0   1.8
# 316               SAC  58  34.3  16.6   4.5   3.1  0.40  0.83  1.7   4.0
# 317               SAC  53  29.8  12.6   3.0   5.1  0.51  1.30  1.5   2.1
# 319               SAC  50  26.8   9.7   4.0   4.2  0.40  1.50  1.1   0.9
# 321               SAC  48  15.5   7.3   2.0   1.1  0.21  0.54  0.9   1.4
# 323               SAC  25  17.6   4.3   2.0   0.9  0.48  0.64  0.5   0.6
# 326               SAC  22   6.9   2.9   1.0   0.9  0.00  0.18  0.2   0.5
# 328               SAC  26   5.8   1.8   0.4   0.6  0.04  0.12  0.2   0.2
# 330               SAC   5   3.4   1.4   0.8   0.2  0.20  0.00  0.2   0.2
#
#       FGA  FG_PCT  FTA  FT_PCT           TEAM_NAME
# 1    16.5   0.477  3.2   0.869      Denver Nuggets
# 4    11.1   0.426  2.2   0.785      Denver Nuggets
# 6     8.3   0.477  1.6   0.789      Denver Nuggets
# 9     6.5   0.412  1.4   0.639      Denver Nuggets
# 10    6.2   0.431  0.7   0.750      Denver Nuggets
# 11    4.2   0.388  1.0   0.824      Denver Nuggets
# 16    1.4   0.357  0.4   0.857      Denver Nuggets
# 17    1.7   0.239  0.1   0.500      Denver Nuggets
# 76   10.4   0.545  5.5   0.615  Philadelphia 76ers
# 77   10.9   0.450  2.9   0.849  Philadelphia 76ers
# 78    7.9   0.422  0.6   0.758  Philadelphia 76ers
# 79    9.8   0.447  1.4   0.894  Philadelphia 76ers
# 81    7.9   0.515  1.6   0.786  Philadelphia 76ers
# 82    7.8   0.408  1.7   0.734  Philadelphia 76ers
# 83    3.7   0.415  0.3   0.500  Philadelphia 76ers
# 84    6.7   0.449  0.9   0.864  Philadelphia 76ers
# 85    6.0   0.396  0.8   0.333  Philadelphia 76ers
# 87    4.0   0.425  1.9   0.614  Philadelphia 76ers
# 90    3.1   0.337  0.4   0.750  Philadelphia 76ers
# 91    0.7   0.429  1.0   0.900  Philadelphia 76ers
# 94    0.5   0.143  0.0   0.000  Philadelphia 76ers
# 95   18.9   0.436  6.3   0.620  Washington Wizards
# 96   22.6   0.482  7.8   0.898  Washington Wizards
# 100   6.2   0.425  0.8   0.522  Washington Wizards
# 101   6.9   0.455  1.1   0.842  Washington Wizards
# 107   5.6   0.295  1.2   0.800  Washington Wizards
# 108   3.9   0.415  1.5   0.895  Washington Wizards
# 109   4.2   0.333  0.8   0.818  Washington Wizards
# 110   2.1   0.387  0.2   0.625  Washington Wizards
# 111   1.7   0.414  0.4   0.833  Washington Wizards
# 313  19.1   0.477  7.2   0.719    Sacramento Kings
# 316  14.1   0.404  1.5   0.837    Sacramento Kings
# 317  10.3   0.472  0.9   0.840    Sacramento Kings
# 319   7.6   0.460  2.3   0.814    Sacramento Kings
# 321   6.4   0.420  0.6   0.828    Sacramento Kings
# 323   3.4   0.442  0.8   0.762    Sacramento Kings
# 326   2.6   0.379  0.5   0.833    Sacramento Kings
# 328   1.6   0.429  0.5   0.417    Sacramento Kings
# 330   1.0   0.600  0.0   0.000    Sacramento Kings
